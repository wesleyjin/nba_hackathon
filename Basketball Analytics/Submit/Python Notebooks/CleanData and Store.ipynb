# %%
import sqlite3
import pandas as pd
import datetime as dt
import sqlalchemy.types as sqltypes
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Connect to db
connection = sqlite3.connect('analytics_track.db')
cursor = connection.cursor()

# %%
# connection.close()

# %%
# !ls
# Out:
# Basketball Analytics Prompt.pdf
# Clean data & store in DB.ipynb
# data.db
# NBA Hackathon - Event Codes.txt
# NBA Hackathon - Game Lineup Data Sample (50 Games).txt
# NBA Hackathon - Play by Play Data Sample (50 Games).txt

# %% [markdown]
# # SQL Interpreter for this Data:
#
# data.db file should be in the directory.
#
# Tables:
# * event_codes (Event_Msg_Type, Action_Type, Event_Msg_Type_Description, Action_Type_Description)
# * game_lineup (Game_id,Period, Person_id, Team_id, status)
# * play_by_play (Game_id, Event_Num, Event_Msg_Type, Period, WC_Time, PC_Time, Action_Type, Option1, Option2, Option3, Team_id, Person1, Person2,Team_id_type)

# %%
def run_query(qry):
    return pd.read_sql_query(qry, connection)

# %%
## EDIT Query Below to interact with DB:

query = """
SELECT DISTINCT Event_Msg_Type, Event_Msg_Type_Description
FROM event_codes
"""

run_query(query)
# Out:
#     Event_Msg_Type Event_Msg_Type_Description
# 0                1                  Made Shot
# 1                2                Missed Shot
# 2                3                 Free Throw
# 3                4                    Rebound
# 4                5                   Turnover
# 5                6                       Foul
# 6                7                  Violation
# 7                8               Substitution
# 8                9                    Timeout
# 9               10                  Jump Ball
# 10              11                   Ejection
# 11              12               Start Period
# 12              13                 End Period
# 13               3                    No Shot

# %% [markdown]
# ## Read in Text Data

# %% [markdown]
# ### Event Codes

# %%
# Read in Text File
df = pd.read_csv('NBA Hackathon - Event Codes.txt', delimiter='\t')

# Take care of strange NaN value on row index 146:
df.set_value(146, 'Action_Type_Description', 'No Shot')

# Remove extra spaces in last two columns:
df["Event_Msg_Type_Description"] = df["Event_Msg_Type_Description"].map(str.strip)
df["Action_Type_Description"] = df["Action_Type_Description"].map(str.strip)

# Save to DB file in 'event_codes' table:
df.to_sql('event_codes', connection, if_exists='replace') # name of SQL table, connection, append

# %%
run_query('SELECT * FROM event_codes').drop(['index'], axis=1).sort_values(by=['Event_Msg_Type', 'Action_Type'])
# Out:
#      Event_Msg_Type  Action_Type Event_Msg_Type_Description  \
# 0                 1            0                  Made Shot
# 1                 1            1                  Made Shot
# 214               1            2                  Made Shot
# 2                 1            3                  Made Shot
# 3                 1            4                  Made Shot
# 4                 1            5                  Made Shot
# 5                 1            6                  Made Shot
# 6                 1            7                  Made Shot
# 7                 1            8                  Made Shot
# 8                 1            9                  Made Shot
# 9                 1           40                  Made Shot
# 10                1           41                  Made Shot
# 11                1           42                  Made Shot
# 138               1           43                  Made Shot
# 12                1           44                  Made Shot
# 13                1           45                  Made Shot
# 215               1           46                  Made Shot
# 14                1           47                  Made Shot
# 15                1           48                  Made Shot
# 16                1           49                  Made Shot
# 17                1           50                  Made Shot
# 216               1           51                  Made Shot
# 18                1           52                  Made Shot
# 139               1           53                  Made Shot
# 19                1           54                  Made Shot
# 20                1           55                  Made Shot
# 21                1           56                  Made Shot
# 22                1           57                  Made Shot
# 23                1           58                  Made Shot
# 24                1           59                  Made Shot
# 25                1           60                  Made Shot
# 217               1           61                  Made Shot
# 26                1           62                  Made Shot
# 27                1           63                  Made Shot
# 28                1           64                  Made Shot
# 29                1           65                  Made Shot
# 30                1           66                  Made Shot
# 31                1           67                  Made Shot
# 163               1           71                  Made Shot
# 166               1           72                  Made Shot
# 167               1           73                  Made Shot
# 168               1           74                  Made Shot
# 169               1           75                  Made Shot
# 164               1           76                  Made Shot
# 165               1           77                  Made Shot
# 233               1           78                  Made Shot
# 170               1           79                  Made Shot
# 171               1           80                  Made Shot
# 172               1           81                  Made Shot
# 173               1           82                  Made Shot
# 174               1           83                  Made Shot
# 175               1           84                  Made Shot
# 176               1           85                  Made Shot
# 177               1           86                  Made Shot
# 178               1           87                  Made Shot
# 179               1           88                  Made Shot
# 180               1           89                  Made Shot
# 181               1           90                  Made Shot
# 182               1           91                  Made Shot
# 183               1           92                  Made Shot
# 184               1           93                  Made Shot
# 185               1           94                  Made Shot
# 186               1           95                  Made Shot
# 187               1           96                  Made Shot
# 241               1           97                  Made Shot
# 242               1           98                  Made Shot
# 243               1           99                  Made Shot
# 244               1          100                  Made Shot
# 245               1          101                  Made Shot
# 246               1          102                  Made Shot
# 247               1          103                  Made Shot
# 248               1          104                  Made Shot
# 249               1          105                  Made Shot
# 250               1          106                  Made Shot
# 251               1          107                  Made Shot
# 252               1          108                  Made Shot
# 253               1          109                  Made Shot
# 254               1          110                  Made Shot
# 32                2            0                Missed Shot
# 140               2            1                Missed Shot
# 33                2            2                Missed Shot
# 218               2            3                Missed Shot
# 34                2            4                Missed Shot
# 35                2            5                Missed Shot
# 36                2            6                Missed Shot
# 37                2            7                Missed Shot
# 38                2            8                Missed Shot
# 39                2            9                Missed Shot
# 40                2           40                Missed Shot
# 41                2           41                Missed Shot
# 42                2           42                Missed Shot
# 43                2           43                Missed Shot
# 219               2           44                Missed Shot
# 44                2           45                Missed Shot
# 141               2           46                Missed Shot
# 45                2           47                Missed Shot
# 46                2           48                Missed Shot
# 47                2           49                Missed Shot
# 48                2           50                Missed Shot
# 49                2           51                Missed Shot
# 50                2           52                Missed Shot
# 51                2           53                Missed Shot
# 52                2           54                Missed Shot
# 53                2           55                Missed Shot
# 54                2           56                Missed Shot
# 55                2           57                Missed Shot
# 220               2           58                Missed Shot
# 56                2           59                Missed Shot
# 57                2           60                Missed Shot
# 58                2           61                Missed Shot
# 59                2           62                Missed Shot
# 60                2           63                Missed Shot
# 61                2           64                Missed Shot
# 62                2           65                Missed Shot
# 63                2           66                Missed Shot
# 64                2           67                Missed Shot
# 188               2           71                Missed Shot
# 189               2           72                Missed Shot
# 192               2           73                Missed Shot
# 193               2           74                Missed Shot
# 229               2           75                Missed Shot
# 194               2           76                Missed Shot
# 190               2           77                Missed Shot
# 195               2           78                Missed Shot
# 196               2           79                Missed Shot
# 197               2           80                Missed Shot
# 198               2           81                Missed Shot
# 199               2           82                Missed Shot
# 200               2           83                Missed Shot
# 201               2           84                Missed Shot
# 202               2           85                Missed Shot
# 230               2           86                Missed Shot
# 203               2           87                Missed Shot
# 204               2           88                Missed Shot
# 231               2           89                Missed Shot
# 205               2           90                Missed Shot
# 206               2           91                Missed Shot
# 207               2           92                Missed Shot
# 208               2           93                Missed Shot
# 209               2           94                Missed Shot
# 210               2           95                Missed Shot
# 191               2           96                Missed Shot
# 255               2           97                Missed Shot
# 256               2           98                Missed Shot
# 257               2           99                Missed Shot
# 258               2          100                Missed Shot
# 259               2          101                Missed Shot
# 260               2          102                Missed Shot
# 261               2          103                Missed Shot
# 262               2          104                Missed Shot
# 263               2          105                Missed Shot
# 264               2          106                Missed Shot
# 265               2          107                Missed Shot
# 266               2          108                Missed Shot
# 267               2          109                Missed Shot
# 268               2          110                Missed Shot
# 146               3            0                    No Shot
# 65                3           10                 Free Throw
# 66                3           11                 Free Throw
# 67                3           12                 Free Throw
# 68                3           13                 Free Throw
# 142               3           14                 Free Throw
# 69                3           15                 Free Throw
# 70                3           16                 Free Throw
# 71                3           17                 Free Throw
# 159               3           18                 Free Throw
# 158               3           19                 Free Throw
# 157               3           20                 Free Throw
# 147               3           21                 Free Throw
# 160               3           22                 Free Throw
# 154               3           25                 Free Throw
# 155               3           26                 Free Throw
# 270               3           27                 Free Throw
# 271               3           28                 Free Throw
# 272               3           29                 Free Throw
# 137               4            0                    Rebound
# 72                4            1                    Rebound
# 73                4            2                    Rebound
# 74                5            0                   Turnover
# 75                5            1                   Turnover
# 76                5            2                   Turnover
# 77                5            3                   Turnover
# 78                5            4                   Turnover
# 79                5            5                   Turnover
# 80                5            6                   Turnover
# 81                5            7                   Turnover
# 82                5            8                   Turnover
# 83                5            9                   Turnover
# 84                5           10                   Turnover
# 85                5           11                   Turnover
# 143               5           12                   Turnover
# 86                5           13                   Turnover
# 87                5           14                   Turnover
# 88                5           15                   Turnover
# 89                5           16                   Turnover
# 221               5           17                   Turnover
# 90                5           18                   Turnover
# 91                5           19                   Turnover
# 92                5           20                   Turnover
# 93                5           21                   Turnover
# 94                5           22                   Turnover
# 95                5           23                   Turnover
# 148               5           24                   Turnover
# 96                5           31                   Turnover
# 149               5           32                   Turnover
# 150               5           33                   Turnover
# 151               5           34                   Turnover
# 161               5           35                   Turnover
# 152               5           36                   Turnover
# 97                5           37                   Turnover
# 162               5           38                   Turnover
# 98                5           39                   Turnover
# 228               5           40                   Turnover
# 99                5           41                   Turnover
# 212               5           42                   Turnover
# 232               5           43                   Turnover
# 239               5           44                   Turnover
# 269               5           45                   Turnover
# 222               6            0                       Foul
# 100               6            1                       Foul
# 101               6            2                       Foul
# 223               6            3                       Foul
# 144               6            4                       Foul
# 102               6            5                       Foul
# 103               6            6                       Foul
# 104               6            7                       Foul
# 105               6            8                       Foul
# 106               6            9                       Foul
# 107               6           10                       Foul
# 108               6           11                       Foul
# 109               6           12                       Foul
# 224               6           13                       Foul
# 110               6           14                       Foul
# 111               6           15                       Foul
# 112               6           16                       Foul
# 113               6           17                       Foul
# 114               6           18                       Foul
# 115               6           19                       Foul
# 153               6           20                       Foul
# 156               6           21                       Foul
# 213               6           25                       Foul
# 234               6           26                       Foul
# 235               6           27                       Foul
# 236               6           28                       Foul
# 237               6           29                       Foul
# 240               6           30                       Foul
# 145               7            0                  Violation
# 116               7            1                  Violation
# 225               7            2                  Violation
# 117               7            3                  Violation
# 118               7            4                  Violation
# 119               7            5                  Violation
# 211               7            6                  Violation
# 120               7           99                  Violation
# 121               8            0               Substitution
# 122               8            3               Substitution
# 123               8           10               Substitution
# 124               8           12               Substitution
# 125               8           14               Substitution
# 126               9            0                    Timeout
# 127               9            1                    Timeout
# 128               9            2                    Timeout
# 129               9            3                    Timeout
# 130               9            4                    Timeout
# 238               9            5                    Timeout
# 273               9            6                    Timeout
# 131              10            0                  Jump Ball
# 226              11            0                   Ejection
# 132              11            1                   Ejection
# 227              11            2                   Ejection
# 133              11            3                   Ejection
# 134              11            4                   Ejection
# 135              12            0               Start Period
# 136              13            0                 End Period
#
#                      Action_Type_Description
# 0                                    No Shot
# 1                                  Jump Shot
# 214                        Running Jump Shot
# 2                                  Hook Shot
# 3                                   Tip Shot
# 4                                 Layup Shot
# 5                         Driving Layup Shot
# 6                                  Dunk Shot
# 7                             Slam Dunk Shot
# 8                          Driving Dunk Shot
# 9                                 Layup Shot
# 10                        Running Layup Shot
# 11                        Driving Layup Shot
# 138                     Alley Oop Layup shot
# 12                        Reverse Layup Shot
# 13                                 Jump Shot
# 215                        Running Jump Shot
# 14                      Turnaround Jump Shot
# 15                                 Dunk Shot
# 16                         Driving Dunk Shot
# 17                         Running Dunk Shot
# 216                        Reverse Dunk Shot
# 18                       Alley Oop Dunk Shot
# 139                                 Tip Shot
# 19                          Running Tip Shot
# 20                                 Hook Shot
# 21                         Running Hook Shot
# 22                         Driving Hook Shot
# 23                      Turnaround Hook Shot
# 24                          Finger Roll Shot
# 25                  Running Finger Roll Shot
# 217                 Driving Finger Roll Shot
# 26               Turnaround Finger Roll Shot
# 27                        Fadeaway Jump Shot
# 28                       Follow Up Dunk Shot
# 29                            Jump Hook Shot
# 30                            Jump Bank Shot
# 31                            Hook Bank Shot
# 163                   Finger Roll Layup Shot
# 166                       Putback Layup Shot
# 167               Driving Reverse Layup Shot
# 168               Running Reverse Layup Shot
# 169           Driving Finger Roll Layup Shot
# 164           Running Finger Roll Layup Shot
# 165                        Driving Jump shot
# 233                       Floating Jump shot
# 170                         Pullup Jump shot
# 171                      Step Back Jump shot
# 172                         Pullup Bank shot
# 173                        Driving Bank shot
# 174                       Fadeaway Bank shot
# 175                        Running Bank shot
# 176                     Turnaround Bank shot
# 177                 Turnaround Fadeaway shot
# 178                        Putback Dunk Shot
# 179                   Driving Slam Dunk Shot
# 180                   Reverse Slam Dunk Shot
# 181                   Running Slam Dunk Shot
# 182                Putback Reverse Dunk Shot
# 183                   Putback Slam Dunk Shot
# 184                   Driving Bank Hook Shot
# 185                      Jump Bank Hook Shot
# 186                   Running Bank Hook Shot
# 187                Turnaround Bank Hook Shot
# 241                           Tip Layup Shot
# 242                       Cutting Layup Shot
# 243           Cutting Finger Roll Layup Shot
# 244             Running Alley Oop Layup Shot
# 245               Driving Floating Jump Shot
# 246          Driving Floating Bank Jump Shot
# 247                Running Pull-Up Jump Shot
# 248                 Step Back Bank Jump Shot
# 249       Turnaround Fadeaway Bank Jump Shot
# 250              Running Alley Oop Dunk Shot
# 251                            Tip Dunk Shot
# 252                        Cutting Dunk Shot
# 253                Driving Reverse Dunk Shot
# 254                Running Reverse Dunk Shot
# 32                                   No Shot
# 140                                Jump Shot
# 33                         Running Jump Shot
# 218                                Hook Shot
# 34                                  Tip Shot
# 35                                Layup Shot
# 36                        Driving Layup Shot
# 37                                 Dunk Shot
# 38                            Slam Dunk Shot
# 39                         Driving Dunk Shot
# 40                                Layup Shot
# 41                        Running Layup Shot
# 42                        Driving Layup Shot
# 43                      Alley Oop Layup shot
# 219                       Reverse Layup Shot
# 44                                 Jump Shot
# 141                        Running Jump Shot
# 45                      Turnaround Jump Shot
# 46                                 Dunk Shot
# 47                         Driving Dunk Shot
# 48                         Running Dunk Shot
# 49                         Reverse Dunk Shot
# 50                       Alley Oop Dunk Shot
# 51                                  Tip Shot
# 52                          Running Tip Shot
# 53                                 Hook Shot
# 54                         Running Hook Shot
# 55                         Driving Hook Shot
# 220                     Turnaround Hook Shot
# 56                          Finger Roll Shot
# 57                  Running Finger Roll Shot
# 58                  Driving Finger Roll Shot
# 59               Turnaround Finger Roll Shot
# 60                        Fadeaway Jump Shot
# 61                       Follow Up Dunk Shot
# 62                            Jump Hook Shot
# 63                            Jump Bank Shot
# 64                            Hook Bank Shot
# 188                   Finger Roll Layup Shot
# 189                       Putback Layup Shot
# 192               Driving Reverse Layup Shot
# 193               Running Reverse Layup Shot
# 229           Driving Finger Roll Layup Shot
# 194           Running Finger Roll Layup Shot
# 190                        Driving Jump shot
# 195                       Floating Jump shot
# 196                         Pullup Jump shot
# 197                      Step Back Jump shot
# 198                         Pullup Bank shot
# 199                        Driving Bank shot
# 200                       Fadeaway Bank shot
# 201                        Running Bank shot
# 202                     Turnaround Bank shot
# 230                 Turnaround Fadeaway shot
# 203                        Putback Dunk Shot
# 204                   Driving Slam Dunk Shot
# 231                   Reverse Slam Dunk Shot
# 205                   Running Slam Dunk Shot
# 206                Putback Reverse Dunk Shot
# 207                   Putback Slam Dunk Shot
# 208                   Driving Bank Hook Shot
# 209                      Jump Bank Hook Shot
# 210                   Running Bank Hook Shot
# 191                Turnaround Bank Hook Shot
# 255                           Tip Layup Shot
# 256                       Cutting Layup Shot
# 257           Cutting Finger Roll Layup Shot
# 258             Running Alley Oop Layup Shot
# 259               Driving Floating Jump Shot
# 260          Driving Floating Bank Jump Shot
# 261                Running Pull-Up Jump Shot
# 262                 Step Back Bank Jump Shot
# 263       Turnaround Fadeaway Bank Jump Shot
# 264              Running Alley Oop Dunk Shot
# 265                            Tip Dunk Shot
# 266                        Cutting Dunk Shot
# 267                Driving Reverse Dunk Shot
# 268                Running Reverse Dunk Shot
# 146                                  No Shot
# 65                         Free Throw 1 of 1
# 66                         Free Throw 1 of 2
# 67                         Free Throw 2 of 2
# 68                         Free Throw 1 of 3
# 142                        Free Throw 2 of 3
# 69                         Free Throw 3 of 3
# 70                      Free Throw Technical
# 71                     Free Throw Clear Path
# 159               Free Throw Flagrant 1 of 2
# 158               Free Throw Flagrant 2 of 2
# 157               Free Throw Flagrant 1 of 1
# 147              Free Throw Technical 1 of 2
# 160              Free Throw Technical 2 of 2
# 154             Free Throw Clear Path 1 of 2
# 155             Free Throw Clear Path 2 of 2
# 270               Free Throw Flagrant 1 of 3
# 271               Free Throw Flagrant 2 of 3
# 272               Free Throw Flagrant 3 of 3
# 137                                  Unknown
# 72                            Normal Rebound
# 73                         Dead Ball Rebound
# 74                               No Turnover
# 75                                  Bad Pass
# 76                                 Lost Ball
# 77                             Out Of Bounds
# 78                                 Traveling
# 79                                      Foul
# 80                            Double Dribble
# 81                       Discontinue Dribble
# 82                        3 Second Violation
# 83                        5 Second Violation
# 84                        8 Second Violation
# 85                       Shot Clock Turnover
# 143                         Inbound Turnover
# 86                        Backcourt Turnover
# 87                              Illegal Pick
# 88                     Offensive Goaltending
# 89                       Isolation Violation
# 221                           Lane Violation
# 90                       Jump Ball Violation
# 91                     Kicked Ball Violation
# 92                   Illegal Assist Turnover
# 93                          Palming Turnover
# 94                          Post Up Turnover
# 95                  Double Personal Turnover
# 148                       10 Second Violaton
# 96                      Stolen Pass Turnover
# 149                 Opposite Basket Turnover
# 150                    Punched Ball Turnover
# 151                 Swinging Elbows Turnover
# 161               Basket from Below Turnover
# 152                  Illegal Screen Turnover
# 97                   Offensive Foul Turnover
# 162                5 Second Inbound Turnover
# 98               Step Out of Bounds Turnover
# 228         Out of Bounds Lost Ball Turnover
# 99                   Poss Lost Ball Turnover
# 212                  Excess Timeout Turnover
# 232  Player Out of Bounds Violation Turnover
# 239                Too Many Players Turnover
# 269        Out of Bounds - Bad Pass Turnover
# 222                                  No Foul
# 100                                 Personal
# 101                                 Shooting
# 223                               Loose Ball
# 144                                Offensive
# 102                                  Inbound
# 103                           Away From Play
# 104                                    Elbow
# 105                                 Punching
# 106                               Clear Path
# 107                          Double Personal
# 108                                Technical
# 109            Non-Unsportsmanlike Technical
# 224                        Hanging Technical
# 110                          Flagrant Type 1
# 111                          Flagrant Type 2
# 112                         Double Technical
# 113                         Defense 3 Second
# 114                          Delay Technical
# 115                       Taunting Technical
# 153                           Player Control
# 156                       Indirect Technical
# 213                 Excess Timeout Technical
# 234                         Offensive Charge
# 235                           Personal Block
# 236                            Personal Take
# 237                           Shooting Block
# 240               Too Many Players Technical
# 145                             No Violation
# 116                            Delay Of Game
# 225                    Defensive Goaltending
# 117                                     Lane
# 118                                Jump Ball
# 119                              Kicked Ball
# 211                              Double Lane
# 120                          Illegal Defense
# 121
# 122
# 123
# 124
# 125
# 126                               No Timeout
# 127                                  Regular
# 128                                    Short
# 129                              Official TV
# 130                                 Official
# 238                                  Advance
# 273                                    Reset
# 131
# 226                              No Ejection
# 132                         Second Technical
# 227                   Second Flagrant Type 1
# 133                    First Flagrant Type 2
# 134                                    Other
# 135
# 136

# %%
pd.options.display.max_rows = 300

# %%
# Count how many action types for each Event_Msg
pd.read_sql_query('SELECT Event_Msg_Type, Event_Msg_Type_Description, count(Action_Type) FROM event_codes GROUP BY Event_Msg_Type', connection)
# 13 types of events.
# Out:
#     Event_Msg_Type Event_Msg_Type_Description  count(Action_Type)
# 0                1                  Made Shot                  78
# 1                2                Missed Shot                  78
# 2                3                 Free Throw                  19
# 3                4                    Rebound                   3
# 4                5                   Turnover                  40
# 5                6                       Foul                  28
# 6                7                  Violation                   8
# 7                8               Substitution                   5
# 8                9                    Timeout                   7
# 9               10                  Jump Ball                   1
# 10              11                   Ejection                   5
# 11              12               Start Period                   1
# 12              13                 End Period                   1

# %% [markdown]
# Events that might be useful in keeping track of +/-:
# * Made shot (2 or 3)
# * Free Throw (0 or 1)
# * Start/End Period can refresh iteration
# * Ejection - player immediately removed from player tracker
# * Substitution - Help keep track of active players (check free throw status first)
#
# Events we don't need to consider:
# * Missed shots: 0 points
# * Rebound
# * Turnover
# * Foul (unless it leads to free throw, which is it's own event)
# * Violation
# * Timeout, JumpBall

# %% [markdown]
# ### Game Lineups

# %%
# Read in Text File
df = pd.read_csv('NBA Hackathon - Game Lineup Data Sample (50 Games).txt', delimiter='\t')

# Save to DB file in 'game_lineup' table:
df.to_sql('game_lineup', connection, if_exists='replace') # name of SQL table, connection, append

# %%
print('First 5 rows of DB:')
# First five rows:
pd.read_sql_query('SELECT * FROM game_lineup', connection).head()

# pd.read_sql_query('SELECT DISTINCT Game_id FROM game_lineup', connection)   ## 50 games
# pd.read_sql_query('SELECT DISTINCT Person_id FROM game_lineup', connection)   ## 389 Players
# pd.read_sql_query('SELECT DISTINCT Period FROM game_lineup', connection)    ## 1-5 (OT is >4)
# pd.read_sql_query('SELECT DISTINCT status FROM game_lineup', connection)   ## always A
# Out:
# First 5 rows of DB:
#    index                           Game_id  Period  \
# 0      0  021fd159b55773fba8157e2090fe0fe2       1
# 1      1  021fd159b55773fba8157e2090fe0fe2       1
# 2      2  021fd159b55773fba8157e2090fe0fe2       1
# 3      3  021fd159b55773fba8157e2090fe0fe2       1
# 4      4  021fd159b55773fba8157e2090fe0fe2       1
#
#                           Person_id                           Team_id status
# 0  881f83d2dee3f18c7d1751659406144e  012059d397c0b7e5a30a5bb89c0b075e      A
# 1  27ea17a8685c4919f157e83fe9cb2d9e  cff694c8186a4bd377de400e4f60fe47      A
# 2  57bbd7e30bc694aeee9ee40c583e6811  cff694c8186a4bd377de400e4f60fe47      A
# 3  cec898a1d355dbfbad8c760615fde1af  012059d397c0b7e5a30a5bb89c0b075e      A
# 4  33963fe856a1523ff46438ba07d1d99f  cff694c8186a4bd377de400e4f60fe47      A

# %% [markdown]
# ### Create Mappings to Turn Codes into Readable Text

# %%
game_ids = run_query('SELECT DISTINCT Game_id FROM game_lineup')

for gid in game_ids['Game_id']:
    print(gid)
# Out:
# 021fd159b55773fba8157e2090fe0fe2
# 03a31e84b194d6c8a2eab5d70ba67acf
# 06bb1d31c63891e2580ff12e4e6505b4
# 07e76f7482773e81e2351d1692e9e5bb
# 0868dee930f69a54541d4ae88b841a37
# 09d46e3d7a8253b7209100650b5afaeb
# 13ced855d491384876c6ab807bd1d3db
# 15d76177caa6022156e83774c2e054d3
# 1eab6189ad9ab246c197575a8c4eebe5
# 1f9e3cb05c031986cf8bc7c0a84cc517
# 2bf4ac0ed9ac1aee8767134d62b34dfe
# 2faabfa663f4dfb9ed83a1482088e092
# 3152e9c330ce200cc189ae64ebdf41fc
# 33f631fec90cc1f08bb16cff5ed52f9b
# 345f285f7c654bf7a03e940a9bc923c3
# 3b753670a0d0df2c35c7ce2e0bc94e6c
# 56ccfaf0adead6f4c7236a01ca0cfbdc
# 598a55c8bf052d039d0fb4ff1a62f98a
# 7fad2269ee0d11ae5069ff23ecb25913
# 87d1574f478f37d13789284b96b4f6cb
# 88012a99d7fd1c169e2360aa5cdf8bfa
# 896bcac9b0f35b250c9fb7a6325d8599
# 8fd2943309c7accc78b41e047e1e9393
# 9db75b921076b5848cba7ca36436147c
# 9dce47bc3cbabd451a9bab758ca5467f
# a109cef8327feae75c3e4885cb4c6e2d
# a32200385b4594cb11f8a19e92c96835
# a442eeb8e92d2941addba3996bd7d0a0
# a55fe197c4ae19094a2303a950c7e70c
# b2abcb6a29ed3d99db98084c96638bff
# b2c59cbe723394436526560db23e6a93
# bd1f8947f5541c2fb22f6328a58f4fc6
# be5f61a5354154b3d7cba7536f189e2f
# bfc4c8f688f511fb76f7fd82a3807f94
# c005dbf89ef3fb55d6f0f0461ada5560
# c18a10de1375b1f12aa17ef6cc540102
# cc638bdf25316add638154b45434aebd
# d0c6985ffc5f03ba09393699467a580a
# d3a00898abc790fd5643d05f996f05f6
# d9eb042455c8f36574d3a52e678a8916
# dadcdbe527d9d72f8b0907796f7559cb
# dc9261160f28c7e28ffe11e9724aa2b3
# dd4d15aab3b091546f9bf65b7f562f26
# ded7de5f5252e901151b00938ce580c1
# e26fa57f2c5e83edc21e3f97b55cbecd
# e3ca2e93a38f7497b6f476c86f5b2136
# e44e31fefaa028c1e9df1a71d4aff555
# f0332f91eb943b64b39ef28daf6639c5
# f385e8caae86b6cb58ed3241c1278ce3
# fdeb2950c4d5209d449ebd2d6afac11e

# %% [markdown]
# 50 Games, 389 Players, 30 Teams Represented in data set. 'Status' column is always "A" so shouldn't matter.

# %% [markdown]
# ### Play by Play

# %%
# Read in Text File
df = pd.read_csv('NBA Hackathon - Play by Play Data Sample (50 Games).txt', delimiter='\t')

# Save to DB file in 'game_lineup' table:
df.to_sql('play_by_play', connection, if_exists='replace') # name of SQL table, connection, append

# %%
# First five rows:
df = pd.read_sql_query('SELECT * FROM play_by_play', connection).head()
df.iloc[0:20]

# pd.read_sql_query('SELECT DISTINCT Game_id FROM game_lineup', connection)   ## 50 games
# pd.read_sql_query('SELECT DISTINCT Person_id FROM game_lineup', connection)   ## 389 Players
# pd.read_sql_query('SELECT DISTINCT Period FROM game_lineup', connection)    ## 1-5 (OT is >4)
# pd.read_sql_query('SELECT DISTINCT status FROM game_lineup', connection)   ## always A
# Out:
#    index                           Game_id  Event_Num  Event_Msg_Type  Period  \
# 0      0  021fd159b55773fba8157e2090fe0fe2          0              12       1
# 1      1  021fd159b55773fba8157e2090fe0fe2          1              10       1
# 2      2  021fd159b55773fba8157e2090fe0fe2          2               2       1
# 3      3  021fd159b55773fba8157e2090fe0fe2          3               4       1
# 4      4  021fd159b55773fba8157e2090fe0fe2          6               6       1
#
#    WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 0   546427     7200            0        0        0        0
# 1   546495     7200            0        0        0        0
# 2   546665     7050            1        3        0        0
# 3   546714     6960            0        0        0        0
# 4   546886     6920            4        0        0        0
#
#                             Team_id                           Person1  \
# 0  1473d70e5646a26de3c52aa1abd85b1f  6bcf6c1f8c373d25fca1579bc4464a91
# 1  012059d397c0b7e5a30a5bb89c0b075e  89706b99ddd00dc05d37ef5cafc04276
# 2  012059d397c0b7e5a30a5bb89c0b075e  cec898a1d355dbfbad8c760615fde1af
# 3  012059d397c0b7e5a30a5bb89c0b075e  307beab25b1021a548b4a47550bc4b25
# 4  cff694c8186a4bd377de400e4f60fe47  c00264c3114d23bac482e9de50fb7d28
#
#                             Person2  Team_id_type
# 0  6bcf6c1f8c373d25fca1579bc4464a91             0
# 1  307beab25b1021a548b4a47550bc4b25             2
# 2  6bcf6c1f8c373d25fca1579bc4464a91             2
# 3  6bcf6c1f8c373d25fca1579bc4464a91             2
# 4  89706b99ddd00dc05d37ef5cafc04276             3
